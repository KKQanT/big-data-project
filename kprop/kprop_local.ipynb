# %%
# !pip install pyspark
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.1.tar.gz (317.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488491 sha256=3006f6b193b3741418e648afc15f1fefbf0babe72881e180412fe75fe1248aee
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.5.1

# %%
from pyspark.sql import SparkSession
import pyspark.sql.functions as F
import pandas as pd
import numpy as np
import time

spark = SparkSession \
        .builder \
        .master("local[*]") \
        .appName("k-prototype-global") \
        .getOrCreate()

sc = spark.sparkContext

# %%
df = pd.read_csv("Retail_Transaction_Dataset.csv")
df = df.dropna()
len(df)
# Out:
# 58714

# %%
# df = pd.read_csv("data.csv")


labels = ["Quantity", "Price", "PaymentMethod","ProductID"]

# from which label are the categorical variables
categorical_labels_start_index = 2

labels[categorical_labels_start_index:]
# Out:
# ['PaymentMethod', 'ProductID']

# %%
df = df[labels]
df.head()
# Out:
#   Quantity      Price PaymentMethod ProductID
# 0        7  80.079844          Cash         C
# 1        4  75.195229          Cash         C
# 2        8  31.528816          Cash         A
# 3        5  98.880218        PayPal         D
# 4        7  93.188512          Cash         A

# %%
df = spark.createDataFrame(df)
df.show(5)
# Out:
# +--------+-----------+-------------+---------+
# |Quantity|      Price|PaymentMethod|ProductID|
# +--------+-----------+-------------+---------+
# |       7|80.07984415|         Cash|        C|
# |       4|75.19522942|         Cash|        C|
# |       8|31.52881648|         Cash|        A|
# |       5|98.88021828|       PayPal|        D|
# |       7|93.18851246|         Cash|        A|
# +--------+-----------+-------------+---------+
# only showing top 5 rows

# %%
df.printSchema()
# Out:
# root
#  |-- Quantity: string (nullable = true)
#  |-- Price: double (nullable = true)
#  |-- PaymentMethod: string (nullable = true)
#  |-- ProductID: string (nullable = true)

# %%
from pyspark.sql.types import LongType

df = df.withColumn("Quantity", df["Quantity"].cast(LongType()))

# %%
df.printSchema()
# Out:
# root
#  |-- Quantity: long (nullable = true)
#  |-- Price: double (nullable = true)
#  |-- PaymentMethod: string (nullable = true)
#  |-- ProductID: string (nullable = true)

# %% [markdown]
# ## Normalising the data

# %%
# min max normalisation for the numerical data
for col in df.columns[:categorical_labels_start_index]:
  minimum = df.agg({col: "min"}).collect()[0][0]
  maximum = df.agg({col: "max"}).collect()[0][0]

  df = df.withColumn(col + '_norm', (df[col] - minimum) / (maximum - minimum))

# %%
df.show(10)
# Out:
# +--------+-----------+-------------+---------+-------------+-------------------+
# |Quantity|      Price|PaymentMethod|ProductID|Quantity_norm|         Price_norm|
# +--------+-----------+-------------+---------+-------------+-------------------+
# |       7|80.07984415|         Cash|        C|         0.75| 0.7786700737595417|
# |       4|75.19522942|         Cash|        C|        0.375| 0.7243958855114194|
# |       8|31.52881648|         Cash|        A|        0.875|0.23920734004228444|
# |       5|98.88021828|       PayPal|        D|          0.5| 0.9875657801905688|
# |       7|93.18851246|         Cash|        A|         0.75| 0.9243237989488644|
# |       3|54.09315249|         Cash|        D|         0.25|0.48992537779848405|
# |       7|13.12193739|       PayPal|        D|         0.75| 0.0346838564079694|
# |       8|56.02516419|   Debit Card|        A|        0.875| 0.5113924478745256|
# |       5|23.85798105|  Credit Card|        B|          0.5|0.15397474972329578|
# |       4| 63.3427768|   Debit Card|        D|        0.375| 0.5927002902070518|
# +--------+-----------+-------------+---------+-------------+-------------------+
# only showing top 10 rows

# %%
df_norm = df.drop("Quantity").drop("Price")
df_norm.show(5)
# Out:
# +-------------+---------+-------------+-------------------+
# |PaymentMethod|ProductID|Quantity_norm|         Price_norm|
# +-------------+---------+-------------+-------------------+
# |         Cash|        C|         0.75| 0.7786700737595417|
# |         Cash|        C|        0.375| 0.7243958855114194|
# |         Cash|        A|        0.875|0.23920734004228444|
# |       PayPal|        D|          0.5| 0.9875657801905688|
# |         Cash|        A|         0.75| 0.9243237989488644|
# +-------------+---------+-------------+-------------------+
# only showing top 5 rows

# %% [markdown]
# ## K prototype

# %%
# make into partitions
rdd = df_norm.rdd.repartition(100)
rdd.cache()
# Out:
# MapPartitionsRDD[75] at coalesce at NativeMethodAccessorImpl.java:0

# %%
type(rdd)
# Out:
# pyspark.rdd.RDD

# %%
import pandas as pd
import numpy as np
from scipy.spatial.distance import euclidean, hamming

class KPrototypes:
    """
    K-Prototypes Clustering Algorithm for mixed numerical and categorical data.
    """
    def __init__(self, data: pd.DataFrame, numerical_cols: list, categorical_cols: list, k_clusters: int):
        """
        Initialize KPrototypes instance.

        Args:
            data (pd.DataFrame): Input data containing both numerical and categorical columns.
            numerical_cols (list): List of numerical column names.
            categorical_cols (list): List of categorical column names.
            k_clusters (int): Number of clusters.
        """
        self.data = data
        self.numerical_cols = numerical_cols
        self.categorical_cols = categorical_cols
        self.k_clusters = k_clusters
        self.centroids = self._initialize_centroids()

    def _initialize_centroids(self) -> pd.DataFrame:
        """
        Initialize centroids by randomly sampling from the data.

        Returns:
            pd.DataFrame: DataFrame containing centroids.
        """
        centroids = self.data.sample(n=self.k_clusters, random_state=42)
        centroids.reset_index(drop=True, inplace=True)
        return centroids

    def _assign_clusters(self) -> list:
        """
        Assign each data point to the nearest centroid.

        Returns:
            list: List of tuples containing index of data point and its assigned cluster.
        """
        clusters = []
        for idx, row in self.data.iterrows():
            min_dis = np.inf
            nearest_cluster = None
            for cen_idx, cen_row in self.centroids.iterrows():
                num_dis = euclidean(row[self.numerical_cols], cen_row[self.numerical_cols])
                cat_dis = hamming(row[self.categorical_cols], cen_row[self.categorical_cols])
                total_dis = num_dis + cat_dis
                if total_dis < min_dis:
                    min_dis = total_dis
                    nearest_cluster = cen_idx
            clusters.append((idx, nearest_cluster))
        return clusters

    def _update_centroids(self, clusters: list) -> None:
        """
        Update centroids based on assigned clusters.

        Args:
            clusters (list): List of tuples containing index of data point and its assigned cluster.
        """
        clusters_df = pd.DataFrame(clusters, columns=['row_index', 'cluster'])
        merged_df = pd.merge(clusters_df, self.data, left_on='row_index', right_index=True)
        self.centroids = merged_df.groupby('cluster').agg({
            col: 'mean' if col in self.numerical_cols else lambda x: x.mode().iloc[0] for col in self.data.columns
        })

    def fit(self) -> None:
        """
        Fit the model to the data by iteratively updating centroids until convergence.
        """
        prev_centroids = None
        step = 0
        while True and step < 20:  # Limiting to 20 steps to prevent infinite loops
            prev_centroids = self.centroids.copy()
            clusters = self._assign_clusters()
            self._update_centroids(clusters)
            step += 1
            if prev_centroids is not None:
                if self.centroids.equals(prev_centroids):
                    print('Convergence reached.')
                    break

    def predict(self, data: pd.DataFrame) -> pd.DataFrame:
        """
        Predict the cluster for each data point.

        Args:
            data (pd.DataFrame): New data for prediction.

        Returns:
            pd.DataFrame: DataFrame with a 'cluster' column indicating the predicted cluster for each data point.
        """
        clusters = []
        for idx, row in data.iterrows():
            min_dis = np.inf
            nearest_cluster = None
            for cen_idx, cen_row in self.centroids.iterrows():
                num_dis = euclidean(row[self.numerical_cols], cen_row[self.numerical_cols])
                cat_dis = hamming(row[self.categorical_cols], cen_row[self.categorical_cols])
                total_dis = num_dis + cat_dis
                if total_dis < min_dis:
                    min_dis = total_dis
                    nearest_cluster = cen_idx
            clusters.append(nearest_cluster)
        data['cluster'] = clusters
        return data

# %%
all_columns = df_norm.columns

cat_columns = [col[0] for col in df_norm.dtypes if col[1] == 'string']

num_columns = [col[0] for col in df_norm.dtypes if col[1] != 'string']

#cat_index = [df_norm.columns.index(col) for col in cat_columns]

def build_model(partition_iter):
  partition_df = pd.DataFrame(partition_iter, columns=all_columns)
  kproto = KPrototypes(partition_df,k_clusters=3,numerical_cols=num_columns,categorical_cols=cat_columns)
  centroids = kproto.fit()

  return [centroids]

centroids = rdd.mapPartitions(build_model).collect()
centroids
# Out:
# [        PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         B       0.440990    0.601331
#  1                Cash         A       0.399601    0.449394
#  2          Debit Card         D       0.619231    0.476343,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0          Debit Card         B       0.594212    0.524036
#  1                Cash         A       0.411585    0.588133
#  2              PayPal         D       0.473837    0.403789,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         A       0.429768    0.403846
#  1         Credit Card         C       0.653289    0.538795
#  2                Cash         D       0.412628    0.584870,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0         Credit Card         D       0.718750    0.447230
#  1         Credit Card         B       0.400463    0.574607
#  2          Debit Card         D       0.381114    0.424790,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0                Cash         B       0.356314    0.488069
#  1              PayPal         B       0.590590    0.567237
#  2         Credit Card         C       0.567661    0.425402,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0                Cash         D       0.412634    0.579922
#  1                Cash         B       0.632199    0.502594
#  2          Debit Card         C       0.478081    0.419112,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         B       0.412709    0.537157
#  1         Credit Card         A       0.486667    0.385231
#  2              PayPal         C       0.586648    0.581790,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0         Credit Card         C       0.408632    0.539829
#  1          Debit Card         A       0.594298    0.564891
#  2          Debit Card         B       0.515457    0.400300,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0          Debit Card         A       0.581573    0.521478
#  1                Cash         D       0.383690    0.582754
#  2         Credit Card         C       0.539583    0.380747,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0          Debit Card         C       0.347917    0.538571
#  1                Cash         A       0.572970    0.524778
#  2         Credit Card         B       0.542488    0.396629,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0          Debit Card         D       0.448803    0.450197
#  1         Credit Card         C       0.421795    0.565326
#  2              PayPal         C       0.658629    0.554701,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         D       0.383197    0.521027
#  1         Credit Card         C       0.457702    0.475711
#  2              PayPal         B       0.616834    0.557823,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0                Cash         B       0.643100    0.547589
#  1              PayPal         C       0.494822    0.431038
#  2         Credit Card         C       0.324342    0.531076,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         C       0.359976    0.577318
#  1                Cash         B       0.528005    0.430954
#  2         Credit Card         C       0.630952    0.470440,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0                Cash         D       0.693939    0.273511
#  1          Debit Card         C       0.415675    0.461169
#  2                Cash         D       0.421779    0.766835,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         A       0.631188    0.484860
#  1         Credit Card         C       0.427083    0.415314
#  2          Debit Card         B       0.436310    0.599154,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0          Debit Card         A       0.466530    0.597370
#  1                Cash         D       0.622696    0.497733
#  2          Debit Card         B       0.381250    0.431546,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         B       0.426913    0.555922
#  1         Credit Card         D       0.430751    0.416873
#  2                Cash         B       0.637228    0.471255,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0          Debit Card         B       0.415605    0.691882
#  1          Debit Card         D       0.377577    0.415584
#  2              PayPal         B       0.639192    0.465462,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0                Cash         B       0.368812    0.521129
#  1          Debit Card         D       0.556386    0.533330
#  2              PayPal         C       0.563144    0.381844,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         B       0.442633    0.422734
#  1          Debit Card         C       0.669595    0.489727
#  2         Credit Card         A       0.438830    0.617397,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         A       0.577415    0.626220
#  1          Debit Card         D       0.382945    0.508699
#  2              PayPal         B       0.547619    0.416022,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0                Cash         A       0.558889    0.408988
#  1          Debit Card         C       0.572794    0.571258
#  2          Debit Card         D       0.333108    0.537612,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         D       0.433575    0.404790
#  1          Debit Card         C       0.626302    0.434752
#  2          Debit Card         A       0.477210    0.625963,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         A       0.401596    0.390655
#  1              PayPal         C       0.635359    0.524470
#  2         Credit Card         B       0.479858    0.579040,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         D       0.578818    0.413481
#  1         Credit Card         B       0.326777    0.501293
#  2                Cash         C       0.587500    0.587265,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0                Cash         D       0.430310    0.575089
#  1              PayPal         A       0.520053    0.369278
#  2              PayPal         C       0.572605    0.586301,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0                Cash         A       0.783069    0.505928
#  1                Cash         A       0.182252    0.342852
#  2         Credit Card         D       0.482212    0.588074,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0                Cash         A       0.399342    0.414937
#  1         Credit Card         C       0.645833    0.520210
#  2          Debit Card         D       0.469444    0.553661,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0          Debit Card         B       0.194268    0.486255
#  1              PayPal         C       0.472222    0.461584
#  2          Debit Card         B       0.804448    0.541055,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         A       0.643713    0.444594
#  1              PayPal         C       0.453911    0.627230
#  2                Cash         B       0.454406    0.412739,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0         Credit Card         C       0.617608    0.581049
#  1              PayPal         A       0.430319    0.551871
#  2          Debit Card         C       0.491124    0.347277,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0          Debit Card         D       0.596264    0.412446
#  1          Debit Card         B       0.382812    0.501887
#  2              PayPal         C       0.512500    0.572393,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0         Credit Card         A       0.507653    0.422466
#  1          Debit Card         C       0.677399    0.518094
#  2              PayPal         D       0.389668    0.556543,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         A       0.345812    0.490599
#  1                Cash         D       0.616955    0.494675
#  2          Debit Card         B       0.535340    0.485440,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0          Debit Card         C       0.662500    0.249342
#  1          Debit Card         C       0.526130    0.751924
#  2         Credit Card         A       0.408425    0.487968,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         B       0.604669    0.422554
#  1         Credit Card         A       0.374475    0.473146
#  2              PayPal         D       0.540995    0.588986,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0          Debit Card         B       0.605381    0.487371
#  1         Credit Card         A       0.407407    0.453190
#  2         Credit Card         C       0.471910    0.625491,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0          Debit Card         C       0.506757    0.379528
#  1         Credit Card         A       0.601601    0.525341
#  2              PayPal         D       0.433787    0.575783,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0          Debit Card         B       0.401906    0.444792
#  1                Cash         A       0.515797    0.548412
#  2          Debit Card         D       0.658784    0.538494,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0          Debit Card         C       0.418782    0.449204
#  1                Cash         A       0.563442    0.631096
#  2         Credit Card         B       0.585696    0.407526,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0          Debit Card         B       0.493243    0.375057
#  1                Cash         B       0.376412    0.566392
#  2              PayPal         D       0.616776    0.569348,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0                Cash         D       0.386957    0.483444
#  1              PayPal         B       0.447209    0.627211
#  2              PayPal         D       0.759740    0.468301,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0         Credit Card         B       0.597973    0.749332
#  1         Credit Card         B       0.326863    0.257675
#  2              PayPal         C       0.602459    0.449336,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0         Credit Card         B       0.607735    0.575463
#  1          Debit Card         A       0.585648    0.439328
#  2         Credit Card         C       0.375000    0.511283,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0          Debit Card         D       0.611538    0.584683
#  1              PayPal         B       0.347368    0.562281
#  2         Credit Card         A       0.544512    0.403772,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0                Cash         D       0.476244    0.416404
#  1         Credit Card         A       0.644324    0.517038
#  2              PayPal         A       0.344136    0.559547,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0          Debit Card         D       0.414535    0.542668
#  1                Cash         A       0.527933    0.371635
#  2                Cash         B       0.577806    0.573437,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0         Credit Card         A       0.411628    0.559591
#  1                Cash         C       0.444368    0.441438
#  2          Debit Card         B       0.691062    0.471716,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         A       0.472926    0.617168
#  1         Credit Card         C       0.603535    0.424790
#  2          Debit Card         C       0.355714    0.454034,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0         Credit Card         B       0.561798    0.432531
#  1                Cash         A       0.545298    0.616270
#  2         Credit Card         C       0.341495    0.444316,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         A       0.561073    0.593876
#  1         Credit Card         B       0.622191    0.398821
#  2         Credit Card         D       0.373705    0.459290,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0         Credit Card         D       0.508880    0.375292
#  1                Cash         A       0.607778    0.543161
#  2              PayPal         D       0.406593    0.584639,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         A       0.458896    0.468847
#  1                Cash         C       0.435829    0.616854
#  2         Credit Card         C       0.582873    0.439450,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0          Debit Card         B       0.595757    0.552042
#  1         Credit Card         D       0.513514    0.387787
#  2              PayPal         D       0.413102    0.565868,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0          Debit Card         D       0.434322    0.601574
#  1         Credit Card         B       0.425118    0.395666
#  2              PayPal         D       0.628109    0.506831,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0         Credit Card         A       0.630236    0.489194
#  1          Debit Card         B       0.392670    0.581019
#  2              PayPal         D       0.479567    0.438475,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         D       0.591216    0.562268
#  1          Debit Card         B       0.404101    0.527686
#  2                Cash         C       0.438079    0.419365,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         A       0.618873    0.489162
#  1                Cash         B       0.381486    0.536429
#  2          Debit Card         B       0.551006    0.474833,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0         Credit Card         B       0.487624    0.527680
#  1                Cash         C       0.584375    0.433132
#  2              PayPal         A       0.342420    0.515668,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         D       0.623008    0.422347
#  1                Cash         D       0.241071    0.467315
#  2                Cash         C       0.523474    0.572345,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0                Cash         D       0.627058    0.543710
#  1              PayPal         C       0.564413    0.378211
#  2                Cash         C       0.259934    0.510069,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0         Credit Card         C       0.391304    0.623016
#  1          Debit Card         B       0.407676    0.459239
#  2         Credit Card         D       0.647606    0.505097,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0          Debit Card         B       0.657500    0.450084
#  1              PayPal         A       0.369565    0.512063
#  2          Debit Card         D       0.496094    0.548775,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         C       0.483463    0.527599
#  1         Credit Card         D       0.166096    0.438856
#  2         Credit Card         D       0.829545    0.528867,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0         Credit Card         C       0.605642    0.492415
#  1                Cash         A       0.504310    0.583812
#  2                Cash         C       0.296584    0.323873,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0          Debit Card         A       0.566667    0.482008
#  1         Credit Card         B       0.383658    0.482756
#  2          Debit Card         D       0.579253    0.595064,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0         Credit Card         D       0.364024    0.464871
#  1         Credit Card         C       0.598901    0.624923
#  2                Cash         B       0.524015    0.473332,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0                Cash         A       0.662290    0.515698
#  1                Cash         C       0.246835    0.353044
#  2          Debit Card         C       0.485825    0.536607,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         B       0.591157    0.573890
#  1                Cash         A       0.551515    0.421525
#  2         Credit Card         D       0.369898    0.511718,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0         Credit Card         D       0.438364    0.569869
#  1              PayPal         C       0.647099    0.481661
#  2              PayPal         A       0.417318    0.392782,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0         Credit Card         A       0.462372    0.565782
#  1                Cash         A       0.620711    0.502880
#  2          Debit Card         D       0.394737    0.404461,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0                Cash         B       0.638808    0.505149
#  1          Debit Card         C       0.376638    0.515169
#  2                Cash         D       0.511905    0.411541,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0         Credit Card         D       0.398964    0.419715
#  1          Debit Card         A       0.628157    0.516068
#  2              PayPal         C       0.421482    0.567733,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0         Credit Card         A       0.554952    0.563286
#  1          Debit Card         D       0.614865    0.392419
#  2              PayPal         D       0.405303    0.476923,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0          Debit Card         C       0.388310    0.605214
#  1              PayPal         C       0.553788    0.300326
#  2              PayPal         A       0.589713    0.615393,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         D       0.583125    0.622366
#  1         Credit Card         B       0.359543    0.451309
#  2                Cash         A       0.556373    0.404519,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         C       0.414634    0.419150
#  1          Debit Card         A       0.622596    0.494465
#  2                Cash         D       0.434322    0.629764,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0          Debit Card         A       0.357781    0.553493
#  1         Credit Card         D       0.518204    0.434942
#  2              PayPal         A       0.633644    0.502213,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0          Debit Card         C       0.550661    0.639885
#  1                Cash         D       0.348852    0.451654
#  2         Credit Card         D       0.603293    0.424239,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0          Debit Card         A       0.380753    0.567291
#  1          Debit Card         D       0.744355    0.567420
#  2         Credit Card         D       0.401786    0.369902,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0         Credit Card         C       0.586694    0.452539
#  1                Cash         C       0.355663    0.411708
#  2              PayPal         D       0.500000    0.577102,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         D       0.613479    0.461261
#  1                Cash         C       0.472826    0.439738
#  2                Cash         A       0.439815    0.620092,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0         Credit Card         C       0.437173    0.532224
#  1              PayPal         A       0.648840    0.543073
#  2          Debit Card         B       0.414024    0.384340,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0                Cash         A       0.418505    0.559409
#  1              PayPal         D       0.367568    0.418127
#  2         Credit Card         C       0.636194    0.502518,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         D       0.421622    0.416893
#  1         Credit Card         A       0.628205    0.506853
#  2          Debit Card         C       0.425595    0.574055,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         B       0.456030    0.468198
#  1                Cash         C       0.650136    0.494465
#  2         Credit Card         C       0.343599    0.525392,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         A       0.448671    0.602728
#  1         Credit Card         D       0.419154    0.455014
#  2                Cash         B       0.638049    0.541412,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         D       0.617568    0.519157
#  1                Cash         B       0.473718    0.391574
#  2          Debit Card         C       0.420238    0.570411,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         D       0.662293    0.568186
#  1          Debit Card         C       0.452736    0.555768
#  2              PayPal         A       0.376202    0.436587,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         D       0.400610    0.497032
#  1         Credit Card         B       0.534884    0.413985
#  2                Cash         C       0.588615    0.618500,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0                Cash         A       0.581064    0.426689
#  1              PayPal         C       0.599619    0.585501
#  2              PayPal         B       0.350785    0.480204,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0         Credit Card         D       0.684812    0.530725
#  1          Debit Card         A       0.431592    0.540905
#  2                Cash         C       0.460591    0.380047,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0         Credit Card         D       0.490500    0.561396
#  1                Cash         B       0.790107    0.486266
#  2                Cash         B       0.186275    0.453682,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0                Cash         A       0.642763    0.407680
#  1                Cash         D       0.392500    0.441495
#  2         Credit Card         B       0.490000    0.586292,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         A       0.393544    0.379103
#  1         Credit Card         B       0.411765    0.589469
#  2              PayPal         C       0.625000    0.461183,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0              PayPal         B       0.592896    0.427789
#  1                Cash         C       0.352064    0.488428
#  2          Debit Card         D       0.539021    0.582551,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0          Debit Card         B       0.396571    0.465427
#  1                Cash         D       0.643895    0.487600
#  2              PayPal         D       0.432943    0.591562,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0                Cash         B       0.332672    0.471287
#  1         Credit Card         C       0.626963    0.506753
#  2          Debit Card         A       0.518204    0.496419,
#          PaymentMethod ProductID  Quantity_norm  Price_norm
#  cluster
#  0                Cash         B       0.658245    0.506722
#  1              PayPal         D       0.494845    0.499058
#  2          Debit Card         A       0.368056    0.506756]

# %%
df = pd.concat(centroids, ignore_index=True)

# %%
k_proto = KPrototypes(df, numerical_cols = num_columns, categorical_cols=cat_columns, k_clusters = 3)
centroid = k_proto.fit()
# Out:
#         PaymentMethod ProductID  Quantity_norm  Price_norm
# cluster
# 0                Cash         B       0.533090    0.499590
# 1          Debit Card         C       0.484253    0.526806
# 2         Credit Card         C       0.467075    0.470309
#         PaymentMethod ProductID  Quantity_norm  Price_norm
# cluster
# 0                Cash         B       0.539388    0.504580
# 1          Debit Card         C       0.484618    0.527185
# 2         Credit Card         C       0.467390    0.467219
#         PaymentMethod ProductID  Quantity_norm  Price_norm
# cluster
# 0                Cash         B       0.539401    0.506369
# 1          Debit Card         C       0.484618    0.527185
# 2         Credit Card         C       0.468815    0.465981
#         PaymentMethod ProductID  Quantity_norm  Price_norm
# cluster
# 0                Cash         B       0.539415    0.507107
# 1          Debit Card         C       0.482845    0.526421
# 2         Credit Card         C       0.469680    0.465425
#         PaymentMethod ProductID  Quantity_norm  Price_norm
# cluster
# 0                Cash         B       0.539415    0.507107
# 1          Debit Card         C       0.481229    0.527163
# 2         Credit Card         C       0.471234    0.465382
#         PaymentMethod ProductID  Quantity_norm  Price_norm
# cluster
# 0                Cash         B       0.539415    0.507107
# 1          Debit Card         C       0.481229    0.527163
# 2         Credit Card         C       0.471234    0.465382
# Breaking

# %%
centroid.to_csv('centroids_local.csv')
